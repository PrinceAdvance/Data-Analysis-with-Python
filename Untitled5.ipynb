# %% [markdown]
# <a href="https://colab.research.google.com/github/PrinceAdvance/Data-Analysis-with-Python/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
pd.options.display.max_rows = 10
